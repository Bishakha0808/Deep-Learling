# %%
# importing libraries
import numpy as np # Importing the numpy library for array operations and mathematical functions
import pandas as pd # Use for exploring the data 
import seaborn as sns # it has also plot
import matplotlib.pyplot as plt # for some extra plot functions
import plotly.express as px # this library can makes interactive plots

# %%
shop = pd.read_csv('/kaggle/input/shopping-trends/shopping_trends_updated.csv')

# %%
shop.shape
# Out:
# (3900, 18)

# %%
shop.dtypes
# Out:
# Customer ID                 int64
# Age                         int64
# Gender                     object
# Item Purchased             object
# Category                   object
# Purchase Amount (USD)       int64
# Location                   object
# Size                       object
# Color                      object
# Season                     object
# Review Rating             float64
# Subscription Status        object
# Shipping Type              object
# Discount Applied           object
# Promo Code Used            object
# Previous Purchases          int64
# Payment Method             object
# Frequency of Purchases     object
# dtype: object

# %%
shop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
shop.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
shop['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
shop['Category'].unique()
# Out:
# array(['Clothing', 'Footwear', 'Outerwear', 'Accessories'], dtype=object)

# %%
shop['Size'].unique()
# Out:
# array(['L', 'S', 'M', 'XL'], dtype=object)

# %%
shop['Subscription Status'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
shop['Shipping Type'].unique()
# Out:
# array(['Express', 'Free Shipping', 'Next Day Air', 'Standard',
#        '2-Day Shipping', 'Store Pickup'], dtype=object)

# %%
shop['Discount Applied'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
shop['Discount Applied'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
shop['Payment Method'].unique()
# Out:
# array(['Venmo', 'Cash', 'Credit Card', 'PayPal', 'Bank Transfer',
#        'Debit Card'], dtype=object)

# %%
shop['Age'].value_counts()
# Out:
# Age
# 69    88
# 57    87
# 41    86
# 25    85
# 49    84
# 54    83
# 27    83
# 50    83
# 62    83
# 32    82
# 58    81
# 19    81
# 42    80
# 31    79
# 28    79
# 43    79
# 37    77
# 29    76
# 46    76
# 63    75
# 59    75
# 68    75
# 56    74
# 36    74
# 52    73
# 64    73
# 55    73
# 51    72
# 65    72
# 45    72
# 40    72
# 35    72
# 47    71
# 66    71
# 30    71
# 23    71
# 53    70
# 38    70
# 18    69
# 26    69
# 21    69
# 34    68
# 39    68
# 48    68
# 24    68
# 70    67
# 22    66
# 61    65
# 60    65
# 33    63
# 20    62
# 67    54
# 44    51
# Name: count, dtype: int64

# %%
shop['Age'].unique()
# Out:
# array([55, 19, 50, 21, 45, 46, 63, 27, 26, 57, 53, 30, 61, 65, 64, 25, 52,
#        66, 31, 56, 18, 38, 54, 33, 36, 35, 29, 70, 69, 67, 20, 39, 42, 68,
#        49, 59, 47, 40, 41, 48, 22, 24, 44, 37, 58, 32, 62, 51, 28, 43, 34,
#        23, 60])

# %%
shop['Age'].mean()
# Out:
# 44.06846153846154

# %%
shop['Age_category'] = pd.cut(shop['Age'], bins= [0,15, 18 , 30 , 50 , 70] , labels= ['child' , 'teen' , 'Young Adults' ,'Middle -Aged Adults' , 'old'] )

# %%
fig = px.histogram(shop , y = 'Age' , x = 'Age_category')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
shop.groupby('Category')['Item Purchased'].value_counts()
# Out:
# Category     Item Purchased
# Accessories  Jewelry           171
#              Sunglasses        161
#              Belt              161
#              Scarf             157
#              Hat               154
#              Handbag           153
#              Backpack          143
#              Gloves            140
# Clothing     Blouse            171
#              Pants             171
#              Shirt             169
#              Dress             166
#              Sweater           164
#              Socks             159
#              Skirt             158
#              Shorts            157
#              Hoodie            151
#              T-shirt           147
#              Jeans             124
# Footwear     Sandals           160
#              Shoes             150
#              Sneakers          145
#              Boots             144
# Outerwear    Jacket            163
#              Coat              161
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
# Initialize LabelEncoder
label_encoder_category = LabelEncoder()
label_encoder_item = LabelEncoder()

# Apply Label Encoding
shop['Category'] = label_encoder_category.fit_transform(shop['Category'])
shop['Item Purchased'] = label_encoder_item.fit_transform(shop['Item Purchased'])

# %%
shop['Item Purchased'].dtypes
# Out:
# dtype('int64')

# %%
shop['Category'].dtypes
# Out:
# dtype('int64')

# %%
shop.dtypes
# Out:
# Customer ID                  int64
# Age                          int64
# Gender                      object
# Item Purchased               int64
# Category                     int64
# Purchase Amount (USD)        int64
# Location                    object
# Size                        object
# Color                       object
# Season                      object
# Review Rating              float64
# Subscription Status         object
# Shipping Type               object
# Discount Applied            object
# Promo Code Used             object
# Previous Purchases           int64
# Payment Method              object
# Frequency of Purchases      object
# Age_category              category
# dtype: object

# %%
shop['Location'] = label_encoder_item.fit_transform(shop['Location'])
shop['Size'] = label_encoder_item.fit_transform(shop['Size'])
shop['Color'] = label_encoder_item.fit_transform(shop['Color'])
shop['Season'] = label_encoder_item.fit_transform(shop['Season'])

# %%
shop.dtypes
# Out:
# Customer ID                  int64
# Age                          int64
# Gender                      object
# Item Purchased               int64
# Category                     int64
# Purchase Amount (USD)        int64
# Location                     int64
# Size                         int64
# Color                        int64
# Season                       int64
# Review Rating              float64
# Subscription Status         object
# Shipping Type               object
# Discount Applied            object
# Promo Code Used             object
# Previous Purchases           int64
# Payment Method              object
# Frequency of Purchases      object
# Age_category              category
# dtype: object

# %%
shop['Subscription Status'] = label_encoder_item.fit_transform(shop['Subscription Status'])
shop['Shipping Type'] = label_encoder_item.fit_transform(shop['Shipping Type'])
shop['Discount Applied'] = label_encoder_item.fit_transform(shop['Discount Applied'])
shop['Promo Code Used'] = label_encoder_item.fit_transform(shop['Promo Code Used'])
shop['Payment Method'] = label_encoder_item.fit_transform(shop['Payment Method'])
shop['Frequency of Purchases'] = label_encoder_item.fit_transform(shop['Frequency of Purchases'])

# %%
shop['Frequency of Purchases'].unique
# Out:
# <bound method Series.unique of 0       3
# 1       3
# 2       6
# 3       6
# 4       0
#        ..
# 3895    6
# 3896    1
# 3897    5
# 3898    6
# 3899    5
# Name: Frequency of Purchases, Length: 3900, dtype: int64>

# %%
fig = px.histogram(shop , x = 'Item Purchased')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns
# #Detecting outliers
# #looking at the scaled features
# colours = ["#D0DBEE", "#C2C4E2", "#EED4E5", "#D1E6DC", "#BDE2E2"]
# plt.figure(figsize=(20,10))
# sns.boxenplot(data = shop['Age'],palette = colours)
# plt.xticks(rotation=90)
# plt.show()

# %%
fig = px.histogram(shop , x = 'Item Purchased' , color = 'Category')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(shop , x = 'Season' , range_y= [200 , 1500] )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
shop['Subscription Status'].unique()
# Out:
# array([1, 0])

# %%
sns.barplot(shop  , x = 'Subscription Status' , y = 'Purchase Amount (USD)')
# Out:
# <Axes: xlabel='Subscription Status', ylabel='Purchase Amount (USD)'>

# %%
shop.groupby('Subscription Status')['Purchase Amount (USD)'].mean()
# Out:
# Subscription Status
# 0    59.865121
# 1    59.491928
# Name: Purchase Amount (USD), dtype: float64

# %%
shop.groupby('Payment Method')['Purchase Amount (USD)'].mean().sort_values(ascending= False)
# Out:
# Payment Method
# 3    60.915094
# 2    60.074516
# 0    59.712418
# 1    59.704478
# 4    59.245199
# 5    58.949527
# Name: Purchase Amount (USD), dtype: float64

# %%
sns.barplot(shop ,x='Payment Method' , y = 'Purchase Amount (USD)')
# Out:
# <Axes: xlabel='Payment Method', ylabel='Purchase Amount (USD)'>

# %%
shop_groupby  = shop.groupby('Promo Code Used')['Purchase Amount (USD)'].sum().reset_index()

# %%
fig = px.sunburst(shop , path=['Gender' , 'Promo Code Used'] , values='Purchase Amount (USD)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
shop_group = shop.groupby('Size')['Purchase Amount (USD)'].sum().reset_index()

# %%
fig  = px.bar(shop_group , x = 'Size' , y ='Purchase Amount (USD)'  )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
shop.groupby('Category')['Shipping Type'].value_counts().sort_values(ascending= False)
# Out:
# Category  Shipping Type
# 1         4                297
#           2                294
#           3                293
#           1                290
#           5                282
#           0                281
# 0         5                217
#           3                211
#           4                208
#           0                206
#           1                203
#           2                195
# 2         2                122
#           4                100
#           5                 98
#           1                 96
#           3                 93
#           0                 90
# 3         2                 64
#           1                 57
#           5                 53
#           3                 51
#           0                 50
#           4                 49
# Name: count, dtype: int64

# %%
shop['Shipping_Category'] =shop['Shipping Type'].map({'Express': 0, 'Free Shipping': 1, 'Next Day Air': 2,
                                                       'Standard': 3, '2-Day Shipping': 4, 'Store Pickup': 5})

# %%
shop['Category'].unique()
# Out:
# array([1, 2, 3, 0])

# %%
shop['Category_num'] =shop['Category'].map({'Clothing':1, 'Footwear':2, 'Outerwear':3, 'Accessories':4})

# %%
shop['Age_category'].unique()
# Out:
# ['old', 'Young Adults', 'Middle -Aged Adults', 'teen']
# Categories (5, object): ['child' < 'teen' < 'Young Adults' < 'Middle -Aged Adults' < 'old']

# %%
shop[['Age' , 'Age_category']]
# Out:
#       Age         Age_category
# 0      55                  old
# 1      19         Young Adults
# 2      50  Middle -Aged Adults
# 3      21         Young Adults
# 4      45  Middle -Aged Adults
# ...   ...                  ...
# 3895   40  Middle -Aged Adults
# 3896   52                  old
# 3897   46  Middle -Aged Adults
# 3898   44  Middle -Aged Adults
# 3899   52                  old
#
# [3900 rows x 2 columns]

# %%
shop_group = shop.groupby('Frequency of Purchases')['Age'].sum()

# %%
px.sunburst(shop , path=['Frequency of Purchases','Age_category'] , values='Age')
# Out:
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:1727: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
shop.groupby('Category')['Shipping Type'].value_counts().sort_values(ascending= False)
# Out:
# Category  Shipping Type
# 1         4                297
#           2                294
#           3                293
#           1                290
#           5                282
#           0                281
# 0         5                217
#           3                211
#           4                208
#           0                206
#           1                203
#           2                195
# 2         2                122
#           4                100
#           5                 98
#           1                 96
#           3                 93
#           0                 90
# 3         2                 64
#           1                 57
#           5                 53
#           3                 51
#           0                 50
#           4                 49
# Name: count, dtype: int64

# %%
shop['Shipping_Category'] =shop['Shipping Type'].map({'Express': 0, 'Free Shipping': 1, 'Next Day Air': 2,
                                                       'Standard': 3, '2-Day Shipping': 4, 'Store Pickup': 5})

# %%
shop['Category'].unique()
# Out:
# array([1, 2, 3, 0])

# %%
shop['Category_num'] =shop['Category'].map({'Clothing':1, 'Footwear':2, 'Outerwear':3, 'Accessories':4})

# %% [markdown]
# **Purchase of Customer**

# %%
shop.groupby('Discount Applied')['Purchase Amount (USD)'].sum().reset_index()
# Out:
#    Discount Applied  Purchase Amount (USD)
# 0                 0                 133670
# 1                 1                  99411

# %%
shop_group = shop.groupby('Discount Applied')['Purchase Amount (USD)'].sum().reset_index()

# %%
px.histogram(shop_group , x = 'Discount Applied' , y = 'Purchase Amount (USD)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Color of Product**

# %%
px.histogram(shop , x = 'Color')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
shop['Color'].value_counts()
# Out:
# Color
# 13    177
# 24    174
# 19    173
# 20    172
# 8     169
# 1     167
# 5     166
# 22    166
# 7     159
# 12    158
# 14    154
# 4     153
# 16    153
# 2     152
# 11    152
# 17    151
# 15    149
# 18    148
# 0     147
# 9     147
# 10    147
# 21    145
# 23    142
# 3     141
# 6     138
# Name: count, dtype: int64

# %% [markdown]
# **Average number of product purchase**

# %%
shop['Previous Purchases'].mean()
# Out:
# 25.35153846153846

# %% [markdown]
# Location

# %%
shop.groupby('Location')['Purchase Amount (USD)'].mean().sort_values(ascending = False)
# Out:
# Location
# 1     67.597222
# 37    66.567568
# 2     66.553846
# 47    63.876543
# 27    63.379310
# 46    63.328767
# 33    62.891566
# 45    62.883117
# 43    62.577465
# 21    62.095890
# 41    61.974026
# 30    61.901235
# 38    61.444444
# 42    61.194805
# 3     61.113924
# 12    61.054348
# 23    61.037500
# 20    60.888889
# 14    60.884058
# 32    60.794872
# 49    60.690141
# 40    60.514286
# 31    60.425287
# 34    60.376623
# 25    60.250000
# 11    60.075269
# 26    59.448276
# 28    59.422535
# 0     59.112360
# 4     59.000000
# 13    58.924051
# 9     58.797468
# 39    58.407895
# 35    58.346667
# 24    57.913580
# 10    57.723077
# 17    57.714286
# 36    57.337838
# 44    57.176471
# 18    56.987013
# 29    56.746269
# 22    56.556818
# 5     56.293333
# 48    55.946667
# 8     55.852941
# 19    55.755814
# 16    55.721519
# 7     55.325581
# 15    54.555556
# 6     54.179487
# Name: Purchase Amount (USD), dtype: float64

# %%
shop.groupby('Location')['Purchase Amount (USD)'].mean().reset_index()
# Out:
#     Location  Purchase Amount (USD)
# 0          0              59.112360
# 1          1              67.597222
# 2          2              66.553846
# 3          3              61.113924
# 4          4              59.000000
# 5          5              56.293333
# 6          6              54.179487
# 7          7              55.325581
# 8          8              55.852941
# 9          9              58.797468
# 10        10              57.723077
# 11        11              60.075269
# 12        12              61.054348
# 13        13              58.924051
# 14        14              60.884058
# 15        15              54.555556
# 16        16              55.721519
# 17        17              57.714286
# 18        18              56.987013
# 19        19              55.755814
# 20        20              60.888889
# 21        21              62.095890
# 22        22              56.556818
# 23        23              61.037500
# 24        24              57.913580
# ...

# %%
shop_group = shop.groupby('Location')['Purchase Amount (USD)'].mean().reset_index()

# %%
fig = px.bar(shop_group, x = 'Location' , y = 'Purchase Amount (USD)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Average purchase btn Male & Female

# %%
shop.groupby('Category')['Age'].mean().reset_index()
# Out:
#    Category        Age
# 0         0  44.224194
# 1         1  43.782959
# 2         2  44.442404
# 3         3  44.311728

# %%
shop_group = shop.groupby('Category')['Age'].mean().reset_index()

# %%
px.sunburst(data_frame= shop , path = ['Gender' ,'Age_category'] , values='Purchase Amount (USD)')
# Out:
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:1727: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
shop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   int64
#  4   Category                3900 non-null   int64
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   int64
#  7   Size                    3900 non-null   int64
#  8   Color                   3900 non-null   int64
#  9   Season                  3900 non-null   int64
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   int64
#  12  Shipping Type           3900 non-null   int64
#  13  Discount Applied        3900 non-null   int64
# ...

# %%
shop_group.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  4 non-null      int64
#  1   Age       4 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 192.0 bytes

# %%
shop['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
# pd.get_dummies(shop,columns=['Gender'])
# shop['Gender'].astype(int)
from sklearn.preprocessing import LabelEncoder

# Assuming 'Gender' column contains 'Male' and 'Female'
label_encoder = LabelEncoder()
shop['Gender'] = label_encoder.fit_transform(shop['Gender'])

# %%
shop['Gender'].dtypes
# Out:
# dtype('int64')

# %%
shop['Item Purchased'].unique
# Out:
# <bound method Series.unique of 0        2
# 1       23
# 2       11
# 3       14
# 4        2
#         ..
# 3895     9
# 3896     0
# 3897     1
# 3898    17
# 3899     7
# Name: Item Purchased, Length: 3900, dtype: int64>

# %%
shop['Gender'].dtypes
# Out:
# dtype('int64')

# %%
shop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   int64
#  3   Item Purchased          3900 non-null   int64
#  4   Category                3900 non-null   int64
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   int64
#  7   Size                    3900 non-null   int64
#  8   Color                   3900 non-null   int64
#  9   Season                  3900 non-null   int64
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   int64
#  12  Shipping Type           3900 non-null   int64
#  13  Discount Applied        3900 non-null   int64
# ...

# %% [markdown]
# #  Prediction Using ANN

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
from keras.utils import to_categorical
from keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score
from keras import callbacks

# %%
data = shop

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   int64
#  3   Item Purchased          3900 non-null   int64
#  4   Category                3900 non-null   int64
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   int64
#  7   Size                    3900 non-null   int64
#  8   Color                   3900 non-null   int64
#  9   Season                  3900 non-null   int64
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   int64
#  12  Shipping Type           3900 non-null   int64
#  13  Discount Applied        3900 non-null   int64
# ...

# %%
shop_group.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  4 non-null      int64
#  1   Age       4 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 192.0 bytes

# %%
shop.isnull().sum()
# Out:
# Customer ID                  0
# Age                          0
# Gender                       0
# Item Purchased               0
# Category                     0
# Purchase Amount (USD)        0
# Location                     0
# Size                         0
# Color                        0
# Season                       0
# Review Rating                0
# Subscription Status          0
# Shipping Type                0
# Discount Applied             0
# Promo Code Used              0
# Previous Purchases           0
# Payment Method               0
# Frequency of Purchases       0
# Age_category                 0
# Shipping_Category         3900
# Category_num              3900
# dtype: int64

# %%
# Out:
#   File "<ipython-input-86-b8154116461c>", line 8
#     pd.DataFrame(knn_imputer.fit_transform(df), columns=df.columns)
#     ^
# IndentationError: unexpected indent

# %%
shop.isnull().sum()
# Out:
# Customer ID                  0
# Age                          0
# Gender                       0
# Item Purchased               0
# Category                     0
# Purchase Amount (USD)        0
# Location                     0
# Size                         0
# Color                        0
# Season                       0
# Review Rating                0
# Subscription Status          0
# Shipping Type                0
# Discount Applied             0
# Promo Code Used              0
# Previous Purchases           0
# Payment Method               0
# Frequency of Purchases       0
# Age_category                 0
# Shipping_Category         3900
# Category_num              3900
# dtype: int64

# %%
shop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   int64
#  3   Item Purchased          3900 non-null   int64
#  4   Category                3900 non-null   int64
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   int64
#  7   Size                    3900 non-null   int64
#  8   Color                   3900 non-null   int64
#  9   Season                  3900 non-null   int64
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   int64
#  12  Shipping Type           3900 non-null   int64
#  13  Discount Applied        3900 non-null   int64
# ...

# %%
shop['Age_category'].value_counts()
# Out:
# Age_category
# old                    1476
# Middle -Aged Adults    1475
# Young Adults            880
# teen                     69
# child                     0
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming 'Gender' column contains 'Male' and 'Female'
label_encoder = LabelEncoder()
shop['Age_category'] = label_encoder.fit_transform(shop['Age_category'])

# %%
shop['Age_category'].value_counts()
# Out:
# Age_category
# 2    1476
# 0    1475
# 1     880
# 3      69
# Name: count, dtype: int64

# %%
shop = shop.drop(['Shipping_Category', 'Category_num'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-884faeb44eee> in <cell line: 1>()
# ----> 1 shop = shop.drop(['Shipping_Category', 'Category_num' , 'Customer ID'], axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5342                 weight  1.0     0.8
#    5343         """
# -> 5344         return super().drop(
#    5345             labels=labels,
#    5346             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709         for axis, labels in axes.items():
#    4710             if labels is not None:
# -> 4711                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4712
#    4713         if inplace:
#
# ...

# %%
shop['Age'].value_counts()
# Out:
# Age
# 69    88
# 57    87
# 41    86
# 25    85
# 49    84
# 54    83
# 27    83
# 50    83
# 62    83
# 32    82
# 58    81
# 19    81
# 42    80
# 31    79
# 28    79
# 43    79
# 37    77
# 29    76
# 46    76
# 63    75
# 59    75
# 68    75
# 56    74
# 36    74
# 52    73
# 64    73
# 55    73
# 51    72
# 65    72
# 45    72
# 40    72
# 35    72
# 47    71
# 66    71
# 30    71
# 23    71
# 53    70
# 38    70
# 18    69
# 26    69
# 21    69
# 34    68
# 39    68
# 48    68
# 24    68
# 70    67
# 22    66
# 61    65
# 60    65
# 33    63
# 20    62
# 67    54
# 44    51
# Name: count, dtype: int64

# %%
shop = shop.drop(['Customer ID'], axis=1)

# %%
shop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     3900 non-null   int64
#  1   Gender                  3900 non-null   int64
#  2   Item Purchased          3900 non-null   int64
#  3   Category                3900 non-null   int64
#  4   Purchase Amount (USD)   3900 non-null   int64
#  5   Location                3900 non-null   int64
#  6   Size                    3900 non-null   int64
#  7   Color                   3900 non-null   int64
#  8   Season                  3900 non-null   int64
#  9   Review Rating           3900 non-null   float64
#  10  Subscription Status     3900 non-null   int64
#  11  Shipping Type           3900 non-null   int64
#  12  Discount Applied        3900 non-null   int64
#  13  Promo Code Used         3900 non-null   int64
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
x = shop.drop(["Item Purchased"], axis=1)
y = shop["Item Purchased"]

# Splitting test and training sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

x.shape
# Out:
# (3900, 17)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import callbacks

# Early stopping callback
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001,  # Minimum amount of change to count as an improvement
    patience=20,      # Number of epochs to wait before stopping
    restore_best_weights=True,
)


# Initialize the model
model = Sequential()

# Input layer
model.add(Dense(units=64, kernel_initializer='he_uniform', activation='relu', input_dim=17))
model.add(BatchNormalization())  # Normalize activations
model.add(Dropout(0.3))

# Hidden layers
model.add(Dense(units=64, kernel_initializer='he_uniform', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Dense(units=32, kernel_initializer='he_uniform', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Dense(units=16, kernel_initializer='he_uniform', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

# Output layer
model.add(Dense(units=1, kernel_initializer='he_uniform', activation='linear'))

# Compile the model
opt = Adam(learning_rate=0.0005)  # Adjust learning rate
model.compile(optimizer=opt, loss='mean_squared_error', metrics=['mean_absolute_error'])

# Train the model
history = model.fit(
    x_train, y_train,
    batch_size=32,
    epochs=300,
    callbacks=[early_stopping],
    validation_split=0.2,
    verbose=1
)

# Evaluate the model
results = model.evaluate(x_test, y_test, batch_size=32)
print("Test Loss (MSE):", results[0])
print("Test MAE:", results[1])
# Out:
# Epoch 1/300
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 203.0066 - mean_absolute_error: 12.2773 - val_loss: 178.7657 - val_mean_absolute_error: 11.4696
# Epoch 2/300
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 194.1651 - mean_absolute_error: 11.8972 - val_loss: 176.7424 - val_mean_absolute_error: 11.3831
# Epoch 3/300
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 184.2099 - mean_absolute_error: 11.5651 - val_loss: 172.4934 - val_mean_absolute_error: 11.2056
# Epoch 4/300
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 185.5670 - mean_absolute_error: 11.5686 - val_loss: 166.0892 - val_mean_absolute_error: 10.9405
# Epoch 5/300
# ...

# %%
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5).astype(int)  # Convert probabilities to binary predictions

y_pred = y_pred/10;
y_test= y_test/10;

# Calculate and print accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-794671f06e6d> in <cell line: 8>()
#       6
#       7 # Calculate and print accuracy
# ----> 8 accuracy = accuracy_score(y_test, y_pred)
#       9 print(f"Accuracy: {accuracy * 100:.2f}%")
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     190
#     191             try:
# --> 192                 return func(*args, **kwargs)
#     193             except InvalidParameterError as e:
#     194                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     219
#     220     # Compute accuracy for each possible representation
# ...

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Predictions remain continuous
y_pred = model.predict(x_test)

# Evaluate using regression metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")
print(f"Mean Absolute Error: {mae:.2f}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error: 145.23
# Mean Absolute Error: 11.73

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#BDE2E2", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#C2C4E2", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Model Loss', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.show()

# Plot training & validation mean absolute error (MAE)
plt.figure(figsize=(12, 6))
plt.plot(history.history['mean_absolute_error'], label='Training MAE', color='green')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE', color='red')
plt.title('Model Mean Absolute Error', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Mean Absolute Error', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.show()

# Additional: Compare predictions with true values
y_pred = model.predict(x_test)

plt.figure(figsize=(12, 6))
plt.scatter(range(len(y_test)), y_test, color='blue', label='True Values')
plt.scatter(range(len(y_test)), y_pred, color='red', alpha=0.6, label='Predicted Values')
plt.title('True vs Predicted Values', fontsize=16)
plt.xlabel('Samples', fontsize=14)
plt.ylabel('Values', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.show()
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
